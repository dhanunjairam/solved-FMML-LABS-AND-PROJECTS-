# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanunjairam/solved-FMML-LABS-AND-PROJECTS-/blob/main/Solved_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 18:20:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   182MB/s    in 0.4s
#
# 2023-05-03 18:20:43 (182 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25757  1511.05204v1  Facial expression is temporally dynamic event ...    cs
# 37592  1710.07709v1  In this paper, we present an automated feature...    cs
# 13501   1104.2644v1  This paper explores an idealized dynamic popul...    cs
# 13163  1710.00499v1  In the online multiple testing problem, p-valu...  stat
# 22930  1711.01861v1  Mechanistic models of single-neuron dynamics h...  stat
# ...             ...                                                ...   ...
# 1208   1510.05970v2  We present a method for extracting depth infor...    cs
# 37021  1605.00303v1  Personalization is the process of fitting a mo...    cs
# 33693  1511.04348v1  This paper describes a method for accelerating...    cs
# 22994  1801.03222v1  This paper deals with inference and prediction...  stat
# 7610   1802.04874v1  We propose a simple, tractable lower bound on ...  stat
#
#                                                    title  year  \
# 25757  Learning Expressionlets via Universal Manifold...  2015
# 37592  Solving the "false positives" problem in fraud...  2017
# 13501  Idealized Dynamic Population Sizing for Unifor...  2011
# 13163  Online control of the false discovery rate wit...  2017
# 22930  Flexible statistical inference for mechanistic...  2017
# ...                                                  ...   ...
# 1208   Stereo Matching by Training a Convolutional Ne...  2015
# 37021  A Self-Taught Artificial Agent for Multi-Physi...  2016
# 33693  Large Scale Artificial Neural Network Training...  2015
# 22994  Multivariate Bayesian Structural Time Series M...  2018
# 7610               GILBO: One Metric to Measure Them All  2018
#
#                                                 keywords
# 25757  [expression, temporally, decomposed, occurring...
# 37592  [automated, engineering, dramatically, positiv...
# 13501  [idealized, population, decomposable, foundati...
# 13163  [corresponding, different, hypotheses, hypothe...
# 22930  [mechanistic, extensively, computational, neur...
# ...                                                  ...
# 1208   [extracting, information, rectified, algorithm...
# 37021  [personalization, application, computational, ...
# 33693  [describes, accelerating, artificial, multipli...
# 22994  [inference, prediction, correlated, candidate,...
# 7610   [tractable, information, contained, generative...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25757    [expression, temporally, decomposed, occurring...
# 37592    [automated, engineering, dramatically, positiv...
# 13501    [idealized, population, decomposable, foundati...
# 13163    [corresponding, different, hypotheses, hypothe...
# 22930    [mechanistic, extensively, computational, neur...
#                                ...
# 4        [reinforcement, developed, institute, algorith...
# 12051    [classification, regression, industrial, appli...
# 15131    [irreplaceable, translation, resources, inesti...
# 21670    [restaurant, stochastic, probability, distribu...
# 30241    [introduce, algorithm, analyzing, information,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8764 words.
# Out of those 4573 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e2c19a80-939c-4bbe-9398-ecb0fe3ebb48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2c19a80-939c-4bbe-9398-ecb0fe3ebb48")) {                    Plotly.newPlot(                        "e2c19a80-939c-4bbe-9398-ecb0fe3ebb48",                        [{"x":["constructed","representation","alignment","represented","instantiated","variations","decomposed","semantics","universal","processed","embedding","naturally","occurring","specifically","discriminative","different","discriminant","characterized","outperforms","temporally","spatially","intervals","expression","statistically","corresponding","databases","evaluated","recognition","automated","behavioral","positives","computation","transactions","estimated","associated","dramatically","customers","streaming","automatically","classifier","historical","transaction","prediction","synthesis","algorithm","necessitates","engineering","performance","uniformly","decomposable","idealized","adjusting","carefully","resulting","population","algorithms","foundations","resolution","rejection","simultaneously","procedures","proportion","discovery","meaningful","generalizations","montanari","applications","discoveries","including","hypotheses","incorporate","important","hypothesis","generalized","demonstrate","investing","differing","knowledge","preserving","alleviates","formulated","penalties","immediately","estimates","posterior","approximating","distribution","biophysical","challenging","inference","parameter","furthermore","synthetic","limitation","likelihood","simulator","mechanistic","modelling","neuroscience","parameters","posteriors","distributions","empirically","efficiently","accurately","extensively","empirical","predicted","computational","approaches","multivariate","recordings","identifying","quantitatively","approximate","adaptively","simulations","recurrent","efficient","statistical","neuroscientists","reproduce","estimating","intuitively","probability","conditional","surprisingly","maximizing","principle","estimation","information","filtering","attribution","intermediate","unimportant","potential","retinopathy","contributions","detection","visualization","generating","explaining","gradients","predicting","integrated","assisting","interesting","literature","representations","utterances","suggested","recovered","meanwhile","perturbation","typically","covariance","comparable","sequentially","theoretical","complexity","presented","dimension","understood","principal","approximates","proportionally","component","successful","dimensional","generated","architectures","dimensions","memorization","character","outperform","connected","significantly","algorithmic","wikipedia","benchmark","sequences","introduces","sequential","reference","translation","multidimensional","spatiotemporal","successfully","parallelized","recurrence","surrogate","extremely","dependencies","minibatch","parallelizing","framework","dependency","classification","previously","variational"],"y":[49,346,55,82,4,78,9,95,42,25,108,61,14,180,95,758,14,29,242,18,31,15,47,25,133,60,148,379,80,19,9,147,1,71,121,18,16,14,194,123,28,1,242,48,811,3,67,900,22,5,1,6,27,136,43,591,14,96,4,104,34,10,41,38,10,0,456,5,246,31,58,380,64,57,579,1,7,342,59,8,46,7,13,71,42,15,226,1,249,213,105,137,132,24,63,15,2,50,9,227,2,113,90,153,68,33,156,46,286,446,26,13,79,23,119,19,29,148,434,168,0,5,72,14,185,107,31,35,49,240,691,55,5,30,3,148,4,48,339,34,118,15,36,88,68,3,86,129,243,20,27,9,13,10,116,26,93,14,136,241,161,65,32,32,18,2,81,67,195,183,111,43,3,65,98,68,273,45,19,197,101,75,76,52,105,12,14,87,6,5,8,53,47,2,5,525,36,486,85,49],"type":"bar"},{"x":["constructed","representation","alignment","represented","instantiated","variations","decomposed"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4573,), (4573, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>FOTS</span> <span style=''>Fast</span> <span style=''>Oriented</span> <span style=''>Text</span> <span style=''>Spotting</span> <span style=''>with</span> <span style=''>a</span> <span style=''>Unified</span> <span style=''>Network</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>Incidental</span> <span style=''>scene</span> <span style=''>text</span> <span style=''>spotting</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3098039215686275);'>difficult</span> <span style=''>and</span> <span style=''>valuable</span> <span style='background-color:rgba(0, 255, 0, 0.32203389830508483);'>challenges</span> <span style=''>in</span> <span style=''>the</span> <span style=''>document</span> <span style=''>analysis</span> <span style='background-color:rgba(0, 255, 0, 0.3064516129032259);'>community</span> <span style=''>Most</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>treat</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.5066666666666667);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6162046908315565);'>recognition</span> <span style=''>as</span> <span style=''>separate</span> <span style=''>tasks</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>trainable</span> <span style=''>Fast</span> <span style=''>Oriented</span> <span style=''>Text</span> <span style=''>Spotting</span> <span style=''>(FOTS)</span> <span style=''>network</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneous</span> <span style='background-color:rgba(0, 255, 0, 0.5066666666666667);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6162046908315565);'>recognition</span> <span style=''>sharing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>and</span> <span style=''>visual</span> <span style='background-color:rgba(0, 255, 0, 0.3000940733772343);'>information</span> <span style=''>among</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.46666666666666673);'>complementary</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Specially</span> <span style=''>RoIRotate</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>to</span> <span style=''>share</span> <span style='background-color:rgba(0, 255, 0, 0.6092436974789917);'>convolutional</span> <span style=''>features</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.5066666666666667);'>detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6162046908315565);'>recognition</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Benefiting</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.6712328767123288);'>convolution</span> <span style=''>sharing</span> <span style=''>strategy</span> <span style=''>our</span> <span style=''>FOTS</span> <span style=''>has</span> <span style=''>little</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>overhead</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>baseline</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.50666666666666 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style=''>Ratio</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>bias</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>learning</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>has</span> <span style=''>three</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>(i)</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>chromatography</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>under</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>base</span> <span style=''>measure</span> <span style=''>function</span> <span style=''>(ii)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>post</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>regions</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Partition</span> <span style=''>Function</span> <span style=''>and</span> <span style=''>Random</span> <span style=''>Maximum</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Posteriori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perturbations</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>relate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>to</span> <span style=''>the</span> <span style=''>max</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistics</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3365155131264916);'>variables</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.5161290322580644);'>approximating</span> <span style=''>and</span> <span style=''>bounding</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>using</span> <span style=''>MAP</span> <span style='background-color:rgba(255, 0, 0, 0.30505709624796074);'>inference</span> <span style=''>on</span> <span style=''>randomly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbed</span> <span style=''>models</span> <span style=''>As</span> <span style=''>a</span> <span style=''>result</span> <span style=''>we</span> <span style=''>can</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>MAP</span> <span style=''>solvers</span> <span style=''>such</span> <span style=''>as</span> <span style=''>graph</span> <span style=''>cuts</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>excels</span> <span style=''>in</span> <span style=''>the</span> <span style=''>typical</span> <span style=''>high</span> <span style=''>signal</span> <span style=''>high</span> <span style=''>coupling</span> <span style=''>regime</span> <span style=''>that</span> <span style=''>results</span> <span style=''>in</span> <span style=''>ragged</span> <span style=''>energy</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>landscapes</span> <span style='background-color:rgba(0, 255, 0, 0.3098039215686275);'>difficult</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <br/><br/><span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>based</span> <span style=''>on</span> <span style=''>one</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>broadly</span> <span style=''>used</span> <span style=''>in</span> <span style=''>many</span> <span style=''>applied</span> <span style=''>domains</span> <span style=''>like</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>(eg</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style=''>whether</span> <span style=''>a</span> <span style=''>patient</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cancerous</span> <span style=''>or</span> <span style=''>healthy</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mammography</span> <span style=''>image)</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>etc</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Performance</span> <span style=''>of</span> <span style=''>an</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>crucially</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>used</span> <span style=''>to</span> <span style=''>measure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>in</span> <span style=''>a</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>The</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>(eg</span> <span style=''>cross</span> <span style=''>validation)</span> <span style=''>for</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>used</span> <span style=''>in</span> <span style=''>two</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>not</span> <span style=''>be</span> <span style=''>used</span> <span style=''>directly</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>specific</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>(absence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>second</span> <span style=''>abnormal</span> <span style=''>class</span> <span style=''>data)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>several</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>from</span> <span style=''>binary</span> <span style=''>class</span> <span style=''>case</span> <span style=''>to</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>one</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12343917231537638)
# 	architecture (0.08633606849803782)
# 	experimental (0.131287905815198)
# 	segmentation (0.07063860149839457)
# 	processing (0.10346057795219407)
# 	information (0.2465215840171245)
# 	detection (0.12094184801997859)
# 	different (0.27042454513021763)
# 	convolutional (0.13663931501962184)
# 	recognition (0.13521227256510882)
#
# Some Statistics words are:
# 	likelihood (0.10766149223835754)
# 	estimation (0.17325988983475213)
# 	variables (0.1402103154732098)
# 	algorithm (0.38057085628442666)
# 	statistical (0.15623435152729093)
# 	theoretical (0.14772158237356034)
# 	distribution (0.18027040560841262)
# 	dimensional (0.18477716574862293)
# 	inference (0.200300450676014)
# 	regression (0.18828242363545317)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d42f2c63-076f-4f66-b390-d94b5a3354f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42f2c63-076f-4f66-b390-d94b5a3354f6")) {                    Plotly.newPlot(                        "d42f2c63-076f-4f66-b390-d94b5a3354f6",                        [{"x":["constructed","representation","alignment","represented","instantiated","variations","decomposed","semantics","universal","processed","embedding","naturally","occurring","specifically","discriminative","different","discriminant","characterized","outperforms","temporally","spatially","intervals","expression","statistically","corresponding","databases","evaluated","recognition","automated","behavioral","positives","computation","transactions","estimated","associated","dramatically","customers","streaming","automatically","classifier","historical","transaction","prediction","synthesis","algorithm","necessitates","engineering","performance","uniformly","decomposable","idealized","adjusting","carefully","resulting","population","algorithms","foundations","resolution","rejection","simultaneously","procedures","proportion","discovery","meaningful","generalizations","montanari","applications","discoveries","including","hypotheses","incorporate","important","hypothesis","generalized","demonstrate","investing","differing","knowledge","preserving","alleviates","formulated","penalties","immediately","estimates","posterior","approximating","distribution","biophysical","challenging","inference","parameter","furthermore","synthetic","limitation","likelihood","simulator","mechanistic","modelling","neuroscience","parameters","posteriors","distributions","empirically","efficiently","accurately","extensively","empirical","predicted","computational","approaches","multivariate","recordings","identifying","quantitatively","approximate","adaptively","simulations","recurrent","efficient","statistical","neuroscientists","reproduce","estimating","intuitively","probability","conditional","surprisingly","maximizing","principle","estimation","information","filtering","attribution","intermediate","unimportant","potential","retinopathy","contributions","detection","visualization","generating","explaining","gradients","predicting","integrated","assisting","interesting","literature","representations","utterances","suggested","recovered","meanwhile","perturbation","typically","covariance","comparable","sequentially","theoretical","complexity","presented","dimension","understood","principal","approximates","proportionally","component","successful","dimensional","generated","architectures","dimensions","memorization","character","outperform","connected","significantly","algorithmic","wikipedia","benchmark","sequences","introduces","sequential","reference","translation","multidimensional","spatiotemporal","successfully","parallelized","recurrence","surrogate","extremely","dependencies","minibatch","parallelizing","framework","dependency","classification","previously","variational","variability","approximations","demonstrated","invariant","permutation","requiring","observations","generative","advantages","generation","generalisation","leverages","completion","conditioning","architecture","exchangeable","configure","consequently","conditions","initially","capitalize","parallelism","approximation","blackwellized","implementation","analytical","decentralized","implement","decomposition","variables","operations","alternative","viewpoint","statistics","combination","interpret","introducing","interpretation","processing","leveraging","graphical","undirected","neighborhood","considerable","numerical","augmenting","additionally","selection","regularized","importance","structure","attracted","attention","difficulty","extending"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	montanari
# 	neuroscientists
# 	phenotypes
# 	straggler
# 	equitability
# 	emphdirectly
# 	boundedness
# 	robustify
# 	distributionally
# 	ulcerative
# 	metabolite
# 	multitype
# 	unavailability
# 	colorectal
# 	regularizations
# 	disentangles
# 	factorisation
# 	nonstationarity
# 	precludes
# 	generalised
# Some words which never appear in Statistics papers:
# 	unimportant
# 	retinopathy
# 	settlement
# 	tentative
# 	hybridized
# 	argumentative
# 	persuasion
# 	acceptability
# 	persuasive
# 	shortened
# 	nondeterministic
# 	occlusions
# 	alternatively
# 	compressively
# 	propositional
# 	argumentation
# 	metabolism
# 	progressing
# 	stratification
# 	declarative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0672024046866854e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7608333333333334
